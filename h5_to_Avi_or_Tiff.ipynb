# %%
import h5py
import numpy as np
import os 
import imageio
import glob

# %%
def h5_to_tiff(dirPath, filePath, output_tiff, chunk_size=100):
    """
    Convert a multi-frame HDF5 dataset to a multipage grayscale TIFF.
    
    Parameters:
        dirPath (str): Directory path where the HDF5 file is located.
        filePath (str): Name of the HDF5 file.
        output_tiff (str): Path for the output TIFF file.
        chunk_size (int): Number of frames to process at a time.
    """
    # Open the HDF5 file and read dataset shape
    with h5py.File(dirPath + filePath, 'r') as f_in:
        dset = f_in['data']
        total_frames, height, width = dset.shape
        print("Dataset shape:", dset.shape)
        
        # Open an imageio writer for TIFF in multi-image (append) mode.
        writer = imageio.get_writer(output_tiff, format='TIFF', mode='I')
        
        # Process the dataset in chunks to save memory
        for start in range(0, total_frames, chunk_size):
            end = min(start + chunk_size, total_frames)
            # Process each frame in this chunk
            for i in range(start, end):
                frame = dset[i, :, :]
                # If the frame is not uint8, scale it appropriately.
                if frame.dtype != np.uint8:
                    # Normalize frame data to 0-255 and convert to uint8.
                    frame = ((frame - frame.min()) / (frame.max() - frame.min()) * 255).astype(np.uint8)
                writer.append_data(frame)
                print(f"Processed frame {i+1} of {total_frames}")
        writer.close()
    print(f"Saved {total_frames} frames to {output_tiff} as a multipage TIFF.")

def h5_to_tiff_split(dirPath, filePath, output_dir, max_frames_per_tiff=1000, chunk_size=100):
    """
    Convert a multi-frame HDF5 dataset to multiple multipage grayscale TIFF files,
    each containing up to max_frames_per_tiff frames. The output filenames are based on
    the input file name with an appended integer to indicate ordering.
    
    Parameters:
        dirPath (str): Directory path where the HDF5 file is located.
        filePath (str): Name of the HDF5 file.
        output_dir (str): Directory where the output TIFF files will be saved.
        max_frames_per_tiff (int): Maximum number of frames per TIFF file.
        chunk_size (int): Number of frames to process at a time.
    """
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    input_path = os.path.join(dirPath, filePath)
    base_name, _ = os.path.splitext(filePath)
    
    with h5py.File(input_path, 'r') as f_in:
        dset = f_in['data']
        total_frames, height, width = dset.shape
        print("Dataset shape:", dset.shape)
        
        # Determine the number of output files needed
        num_files = (total_frames + max_frames_per_tiff - 1) // max_frames_per_tiff
        
        for file_index in range(num_files):
            start_frame = file_index * max_frames_per_tiff
            end_frame = min((file_index + 1) * max_frames_per_tiff, total_frames)
            
            # Create output TIFF filename, e.g., "base_name_1.tiff", "base_name_2.tiff", etc.
            output_tiff = os.path.join(output_dir, f"{base_name}_{file_index+1}.tiff")
            writer = imageio.get_writer(output_tiff, format='TIFF', mode='I')
            print(f"Writing frames {start_frame} to {end_frame-1} to {output_tiff}")
            
            # Process the current block in chunks
            for chunk_start in range(start_frame, end_frame, chunk_size):
                chunk_end = min(chunk_start + chunk_size, end_frame)
                for i in range(chunk_start, chunk_end):
                    frame = dset[i, :, :]
                    # Normalize to uint8 if needed
                    if frame.dtype != np.uint8:
                        if frame.max() == frame.min():
                            # If the frame is constant, set it to zeros
                            frame = np.zeros_like(frame, dtype=np.uint8)
                        else:
                            frame = ((frame - frame.min()) / (frame.max() - frame.min()) * 255).astype(np.uint8)
                    writer.append_data(frame)
                    print(f"Processed frame {i+1} of {total_frames}")
            writer.close()
            print(f"Finished writing {output_tiff}")
    
    print("All TIFF files have been saved.")
    
def tiffs_to_h5(tiff_dir, output_h5, dataset_name='data', chunk_size=100, swap_axes=False):
    """
    Combine multiple TIFF files from a directory into a single HDF5 dataset.
    This function reads each TIFF file in chunks to conserve memory.
    
    Before creating the HDF5 file, it scans all TIFF files to determine a common frame
    shape (after applying optional axis swapping) and the total number of frames.
    
    Parameters:
        tiff_dir (str): Directory containing the TIFF files.
        output_h5 (str): Path to the output HDF5 file.
        dataset_name (str): Name of the dataset to create in the HDF5 file.
        chunk_size (int): Number of frames to process at a time.
        swap_axes (bool): If True, transpose each frame (swap first two axes).
                          Use this if the loaded frame dimensions do not match expectations.
    """
    # List all TIFF files in the directory
    tiff_files = sorted(glob.glob(os.path.join(tiff_dir, "*.tif")))
    if not tiff_files:
        raise ValueError(f"No TIFF files found in {tiff_dir}")
    
    total_frames = 0
    common_shape = None  # expected (height, width)
    file_info = []       # list of tuples: (filename, n_frames)
    
    # First pass: determine total frames and common frame shape.
    for tiff_file in tiff_files:
        reader = imageio.get_reader(tiff_file, format='TIFF')
        frame0 = reader.get_data(0)
        if swap_axes:
            frame0 = frame0.T
        # Determine shape and number of frames for this file.
        if frame0.ndim == 2:
            # Multipage TIFF: each page is one 2D frame.
            shape = frame0.shape  # (height, width)
            n_frames_file = reader.get_length()
        elif frame0.ndim == 3:
            # 3D stack stored in one page; assume shape is (height, width, n_slices)
            shape = frame0.shape[:2]
            if reader.get_length() == 1:
                n_frames_file = frame0.shape[2]
            else:
                # In the uncommon case there are multiple pages of 3D stacks,
                # treat each page as one volume and use the first slice's shape.
                n_frames_file = reader.get_length()
                shape = reader.get_data(0).shape[:2]
        else:
            reader.close()
            raise ValueError(f"Unexpected frame dimensions in file: {tiff_file}")
        
        # If common_shape hasn't been set yet, use this file's shape.
        if common_shape is None:
            common_shape = shape
        else:
            # If a file's shape does not match, raise an error (or choose how to resolve it).
            if common_shape != shape:
                reader.close()
                raise ValueError(f"Inconsistent frame shapes: expected {common_shape} but got {shape} in {tiff_file}")
        
        total_frames += n_frames_file
        file_info.append((tiff_file, n_frames_file))
        reader.close()
    
    print(f"Total frames: {total_frames}, Common frame size: {common_shape[0]}x{common_shape[1]}")
    
    # Create the HDF5 file and dataset.
    with h5py.File(output_h5, 'w') as f_out:
        dset = f_out.create_dataset(dataset_name, shape=(total_frames, common_shape[0], common_shape[1]),
                                    dtype=np.uint8, chunks=True)
        current_index = 0
        
        # Second pass: process each file and write frames into the HDF5 dataset.
        for tiff_file, n_frames_file in file_info:
            reader = imageio.get_reader(tiff_file, format='TIFF')
            frame0 = reader.get_data(0)
            if swap_axes:
                frame0 = frame0.T
            # Process files with 2D pages (multipage TIFF)
            if frame0.ndim == 2:
                for start in range(0, n_frames_file, chunk_size):
                    end = min(start + chunk_size, n_frames_file)
                    frames = []
                    for i in range(start, end):
                        frame = reader.get_data(i)
                        if swap_axes:
                            frame = frame.T
                        # Normalize to uint8 if necessary.
                        if frame.dtype != np.uint8:
                            frame = ((frame - frame.min()) / (frame.max() - frame.min() + 1e-8) * 255).astype(np.uint8)
                        frames.append(frame)
                    frames = np.array(frames)
                    num_chunk = frames.shape[0]
                    dset[current_index:current_index+num_chunk, :, :] = frames
                    current_index += num_chunk
                    print(f"Processed frames {current_index}/{total_frames} from {tiff_file}")
            # Process files with a single 3D stack.
            elif frame0.ndim == 3:
                if reader.get_length() == 1:
                    # Assume the stack shape is (height, width, n_slices)
                    n_slices = frame0.shape[2]
                    for start in range(0, n_slices, chunk_size):
                        end = min(start + chunk_size, n_slices)
                        frames = frame0[:, :, start:end]
                        # Convert from (height, width, n_slices) to (n_slices, height, width)
                        frames = np.transpose(frames, (2, 0, 1))
                        if swap_axes:
                            frames = np.array([f.T for f in frames])
                        if frames.dtype != np.uint8:
                            frames = np.array([((f - f.min()) / (f.max() - f.min() + 1e-8)*255).astype(np.uint8) for f in frames])
                        num_chunk = frames.shape[0]
                        dset[current_index:current_index+num_chunk, :, :] = frames
                        current_index += num_chunk
                        print(f"Processed frames {current_index}/{total_frames} from {tiff_file}")
                else:
                    # Handle an unlikely case of multiple pages with 3D stacks.
                    for start in range(0, n_frames_file, chunk_size):
                        end = min(start + chunk_size, n_frames_file)
                        frames = []
                        for i in range(start, end):
                            frame = reader.get_data(i)
                            if swap_axes:
                                frame = frame.T
                            # If the frame is still 3D, take the first slice.
                            if frame.ndim == 3:
                                frame = frame[:, :, 0]
                            if frame.dtype != np.uint8:
                                frame = ((frame - frame.min()) / (frame.max() - frame.min() + 1e-8) * 255).astype(np.uint8)
                            frames.append(frame)
                        frames = np.array(frames)
                        num_chunk = frames.shape[0]
                        dset[current_index:current_index+num_chunk, :, :] = frames
                        current_index += num_chunk
                        print(f"Processed frames {current_index}/{total_frames} from {tiff_file}")
            else:
                reader.close()
                raise ValueError(f"Unexpected frame dimensions in file: {tiff_file}")
            reader.close()
    print(f"All {total_frames} frames have been saved to {output_h5}")

# %%
dirPath = '/scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/'
filePath = '2024-11-12-15-23-47_channel1.h5'
output_avi = dirPath+'2024-11-12-15-23-47_channel1.avi'     # output AVI filename
output_dir = '/scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/'
output_tiff = dirPath+'2024-11-12-15-23-47_channel1.tiff'
fps = 20

# %%
h5_to_tiff_split(dirPath, filePath, output_dir, max_frames_per_tiff=1000, chunk_size=100)
# Out:
# Dataset shape: (3204, 1280, 800)
# Writing frames 0 to 999 to /scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/2024-11-12-15-23-47_channel1_1.tiff
# Processed frame 1 of 3204
# Processed frame 2 of 3204
# Processed frame 3 of 3204
# Processed frame 4 of 3204
# Processed frame 5 of 3204
# Processed frame 6 of 3204
# Processed frame 7 of 3204
# Processed frame 8 of 3204
# Processed frame 9 of 3204
# Processed frame 10 of 3204
# Processed frame 11 of 3204
# Processed frame 12 of 3204
# Processed frame 13 of 3204
# Processed frame 14 of 3204
# Processed frame 15 of 3204
# Processed frame 16 of 3204
# Processed frame 17 of 3204
# Processed frame 18 of 3204
# Processed frame 19 of 3204
# Processed frame 20 of 3204
# Processed frame 21 of 3204
# Processed frame 22 of 3204
# Processed frame 23 of 3204
# Processed frame 24 of 3204
# Processed frame 25 of 3204
# Processed frame 26 of 3204
# Processed frame 27 of 3204
# Processed frame 28 of 3204
# Processed frame 29 of 3204
# Processed frame 30 of 3204
# Processed frame 31 of 3204
# Processed frame 32 of 3204
# Processed frame 33 of 3204
# Processed frame 34 of 3204
# Processed frame 35 of 3204
# Processed frame 36 of 3204
# Processed frame 37 of 3204
# Processed frame 38 of 3204
# Processed frame 39 of 3204
# Processed frame 40 of 3204
# Processed frame 41 of 3204
# Processed frame 42 of 3204
# Processed frame 43 of 3204
# Processed frame 44 of 3204
# Processed frame 45 of 3204
# Processed frame 46 of 3204
# Processed frame 47 of 3204
# Processed frame 48 of 3204
# Processed frame 49 of 3204
# Processed frame 50 of 3204
# Processed frame 51 of 3204
# Processed frame 52 of 3204
# Processed frame 53 of 3204
# Processed frame 54 of 3204
# Processed frame 55 of 3204
# Processed frame 56 of 3204
# Processed frame 57 of 3204
# Processed frame 58 of 3204
# Processed frame 59 of 3204
# Processed frame 60 of 3204
# Processed frame 61 of 3204
# Processed frame 62 of 3204
# Processed frame 63 of 3204
# Processed frame 64 of 3204
# Processed frame 65 of 3204
# Processed frame 66 of 3204
# Processed frame 67 of 3204
# Processed frame 68 of 3204
# Processed frame 69 of 3204
# Processed frame 70 of 3204
# Processed frame 71 of 3204
# Processed frame 72 of 3204
# Processed frame 73 of 3204
# Processed frame 74 of 3204
# Processed frame 75 of 3204
# Processed frame 76 of 3204
# Processed frame 77 of 3204
# Processed frame 78 of 3204
# Processed frame 79 of 3204
# Processed frame 80 of 3204
# Processed frame 81 of 3204
# Processed frame 82 of 3204
# Processed frame 83 of 3204
# Processed frame 84 of 3204
# Processed frame 85 of 3204
# Processed frame 86 of 3204
# Processed frame 87 of 3204
# Processed frame 88 of 3204
# Processed frame 89 of 3204
# Processed frame 90 of 3204
# Processed frame 91 of 3204
# Processed frame 92 of 3204
# Processed frame 93 of 3204
# Processed frame 94 of 3204
# Processed frame 95 of 3204
# Processed frame 96 of 3204
# Processed frame 97 of 3204
# Processed frame 98 of 3204
# Processed frame 99 of 3204
# Processed frame 100 of 3204
# Processed frame 101 of 3204
# Processed frame 102 of 3204
# Processed frame 103 of 3204
# Processed frame 104 of 3204
# Processed frame 105 of 3204
# Processed frame 106 of 3204
# Processed frame 107 of 3204
# Processed frame 108 of 3204
# Processed frame 109 of 3204
# Processed frame 110 of 3204
# Processed frame 111 of 3204
# Processed frame 112 of 3204
# Processed frame 113 of 3204
# Processed frame 114 of 3204
# Processed frame 115 of 3204
# Processed frame 116 of 3204
# Processed frame 117 of 3204
# Processed frame 118 of 3204
# Processed frame 119 of 3204
# Processed frame 120 of 3204
# Processed frame 121 of 3204
# Processed frame 122 of 3204
# Processed frame 123 of 3204
# Processed frame 124 of 3204
# Processed frame 125 of 3204
# Processed frame 126 of 3204
# Processed frame 127 of 3204
# Processed frame 128 of 3204
# Processed frame 129 of 3204
# Processed frame 130 of 3204
# Processed frame 131 of 3204
# Processed frame 132 of 3204
# Processed frame 133 of 3204
# Processed frame 134 of 3204
# Processed frame 135 of 3204
# Processed frame 136 of 3204
# Processed frame 137 of 3204
# Processed frame 138 of 3204
# Processed frame 139 of 3204
# Processed frame 140 of 3204
# Processed frame 141 of 3204
# Processed frame 142 of 3204
# Processed frame 143 of 3204
# Processed frame 144 of 3204
# Processed frame 145 of 3204
# Processed frame 146 of 3204
# Processed frame 147 of 3204
# Processed frame 148 of 3204
# Processed frame 149 of 3204
# Processed frame 150 of 3204
# Processed frame 151 of 3204
# Processed frame 152 of 3204
# Processed frame 153 of 3204
# Processed frame 154 of 3204
# Processed frame 155 of 3204
# Processed frame 156 of 3204
# Processed frame 157 of 3204
# Processed frame 158 of 3204
# Processed frame 159 of 3204
# Processed frame 160 of 3204
# Processed frame 161 of 3204
# Processed frame 162 of 3204
# Processed frame 163 of 3204
# Processed frame 164 of 3204
# Processed frame 165 of 3204
# Processed frame 166 of 3204
# Processed frame 167 of 3204
# Processed frame 168 of 3204
# Processed frame 169 of 3204
# Processed frame 170 of 3204
# Processed frame 171 of 3204
# Processed frame 172 of 3204
# Processed frame 173 of 3204
# Processed frame 174 of 3204
# Processed frame 175 of 3204
# Processed frame 176 of 3204
# Processed frame 177 of 3204
# Processed frame 178 of 3204
# Processed frame 179 of 3204
# Processed frame 180 of 3204
# Processed frame 181 of 3204
# Processed frame 182 of 3204
# Processed frame 183 of 3204
# Processed frame 184 of 3204
# Processed frame 185 of 3204
# Processed frame 186 of 3204
# Processed frame 187 of 3204
# Processed frame 188 of 3204
# Processed frame 189 of 3204
# Processed frame 190 of 3204
# Processed frame 191 of 3204
# Processed frame 192 of 3204
# Processed frame 193 of 3204
# Processed frame 194 of 3204
# Processed frame 195 of 3204
# Processed frame 196 of 3204
# Processed frame 197 of 3204
# Processed frame 198 of 3204
# Processed frame 199 of 3204
# Processed frame 200 of 3204
# Processed frame 201 of 3204
# Processed frame 202 of 3204
# Processed frame 203 of 3204
# Processed frame 204 of 3204
# Processed frame 205 of 3204
# Processed frame 206 of 3204
# Processed frame 207 of 3204
# Processed frame 208 of 3204
# Processed frame 209 of 3204
# Processed frame 210 of 3204
# Processed frame 211 of 3204
# Processed frame 212 of 3204
# Processed frame 213 of 3204
# Processed frame 214 of 3204
# Processed frame 215 of 3204
# Processed frame 216 of 3204
# Processed frame 217 of 3204
# Processed frame 218 of 3204
# Processed frame 219 of 3204
# Processed frame 220 of 3204
# Processed frame 221 of 3204
# Processed frame 222 of 3204
# Processed frame 223 of 3204
# Processed frame 224 of 3204
# Processed frame 225 of 3204
# Processed frame 226 of 3204
# Processed frame 227 of 3204
# Processed frame 228 of 3204
# Processed frame 229 of 3204
# Processed frame 230 of 3204
# Processed frame 231 of 3204
# Processed frame 232 of 3204
# Processed frame 233 of 3204
# Processed frame 234 of 3204
# Processed frame 235 of 3204
# Processed frame 236 of 3204
# Processed frame 237 of 3204
# Processed frame 238 of 3204
# Processed frame 239 of 3204
# Processed frame 240 of 3204
# Processed frame 241 of 3204
# Processed frame 242 of 3204
# Processed frame 243 of 3204
# Processed frame 244 of 3204
# Processed frame 245 of 3204
# Processed frame 246 of 3204
# Processed frame 247 of 3204
# Processed frame 248 of 3204
# Processed frame 249 of 3204
# Processed frame 250 of 3204
# Processed frame 251 of 3204
# Processed frame 252 of 3204
# Processed frame 253 of 3204
# Processed frame 254 of 3204
# Processed frame 255 of 3204
# Processed frame 256 of 3204
# Processed frame 257 of 3204
# Processed frame 258 of 3204
# Processed frame 259 of 3204
# Processed frame 260 of 3204
# Processed frame 261 of 3204
# Processed frame 262 of 3204
# Processed frame 263 of 3204
# Processed frame 264 of 3204
# Processed frame 265 of 3204
# Processed frame 266 of 3204
# Processed frame 267 of 3204
# Processed frame 268 of 3204
# Processed frame 269 of 3204
# Processed frame 270 of 3204
# Processed frame 271 of 3204
# Processed frame 272 of 3204
# Processed frame 273 of 3204
# Processed frame 274 of 3204
# Processed frame 275 of 3204
# Processed frame 276 of 3204
# Processed frame 277 of 3204
# Processed frame 278 of 3204
# Processed frame 279 of 3204
# Processed frame 280 of 3204
# Processed frame 281 of 3204
# Processed frame 282 of 3204
# Processed frame 283 of 3204
# Processed frame 284 of 3204
# Processed frame 285 of 3204
# Processed frame 286 of 3204
# Processed frame 287 of 3204
# Processed frame 288 of 3204
# Processed frame 289 of 3204
# Processed frame 290 of 3204
# Processed frame 291 of 3204
# Processed frame 292 of 3204
# Processed frame 293 of 3204
# Processed frame 294 of 3204
# Processed frame 295 of 3204
# Processed frame 296 of 3204
# Processed frame 297 of 3204
# Processed frame 298 of 3204
# Processed frame 299 of 3204
# Processed frame 300 of 3204
# Processed frame 301 of 3204
# Processed frame 302 of 3204
# Processed frame 303 of 3204
# Processed frame 304 of 3204
# Processed frame 305 of 3204
# Processed frame 306 of 3204
# Processed frame 307 of 3204
# Processed frame 308 of 3204
# Processed frame 309 of 3204
# Processed frame 310 of 3204
# Processed frame 311 of 3204
# Processed frame 312 of 3204
# Processed frame 313 of 3204
# Processed frame 314 of 3204
# Processed frame 315 of 3204
# Processed frame 316 of 3204
# Processed frame 317 of 3204
# Processed frame 318 of 3204
# Processed frame 319 of 3204
# Processed frame 320 of 3204
# Processed frame 321 of 3204
# Processed frame 322 of 3204
# Processed frame 323 of 3204
# Processed frame 324 of 3204
# Processed frame 325 of 3204
# Processed frame 326 of 3204
# Processed frame 327 of 3204
# Processed frame 328 of 3204
# Processed frame 329 of 3204
# Processed frame 330 of 3204
# Processed frame 331 of 3204
# Processed frame 332 of 3204
# Processed frame 333 of 3204
# Processed frame 334 of 3204
# Processed frame 335 of 3204
# Processed frame 336 of 3204
# Processed frame 337 of 3204
# Processed frame 338 of 3204
# Processed frame 339 of 3204
# Processed frame 340 of 3204
# Processed frame 341 of 3204
# Processed frame 342 of 3204
# Processed frame 343 of 3204
# Processed frame 344 of 3204
# Processed frame 345 of 3204
# Processed frame 346 of 3204
# Processed frame 347 of 3204
# Processed frame 348 of 3204
# Processed frame 349 of 3204
# Processed frame 350 of 3204
# Processed frame 351 of 3204
# Processed frame 352 of 3204
# Processed frame 353 of 3204
# Processed frame 354 of 3204
# Processed frame 355 of 3204
# Processed frame 356 of 3204
# Processed frame 357 of 3204
# Processed frame 358 of 3204
# Processed frame 359 of 3204
# Processed frame 360 of 3204
# Processed frame 361 of 3204
# Processed frame 362 of 3204
# Processed frame 363 of 3204
# Processed frame 364 of 3204
# Processed frame 365 of 3204
# Processed frame 366 of 3204
# Processed frame 367 of 3204
# Processed frame 368 of 3204
# Processed frame 369 of 3204
# Processed frame 370 of 3204
# Processed frame 371 of 3204
# Processed frame 372 of 3204
# Processed frame 373 of 3204
# Processed frame 374 of 3204
# Processed frame 375 of 3204
# Processed frame 376 of 3204
# Processed frame 377 of 3204
# Processed frame 378 of 3204
# Processed frame 379 of 3204
# Processed frame 380 of 3204
# Processed frame 381 of 3204
# Processed frame 382 of 3204
# Processed frame 383 of 3204
# Processed frame 384 of 3204
# Processed frame 385 of 3204
# Processed frame 386 of 3204
# Processed frame 387 of 3204
# Processed frame 388 of 3204
# Processed frame 389 of 3204
# Processed frame 390 of 3204
# Processed frame 391 of 3204
# Processed frame 392 of 3204
# Processed frame 393 of 3204
# Processed frame 394 of 3204
# Processed frame 395 of 3204
# Processed frame 396 of 3204
# Processed frame 397 of 3204
# Processed frame 398 of 3204
# Processed frame 399 of 3204
# Processed frame 400 of 3204
# Processed frame 401 of 3204
# Processed frame 402 of 3204
# Processed frame 403 of 3204
# Processed frame 404 of 3204
# Processed frame 405 of 3204
# Processed frame 406 of 3204
# Processed frame 407 of 3204
# Processed frame 408 of 3204
# Processed frame 409 of 3204
# Processed frame 410 of 3204
# Processed frame 411 of 3204
# Processed frame 412 of 3204
# Processed frame 413 of 3204
# Processed frame 414 of 3204
# Processed frame 415 of 3204
# Processed frame 416 of 3204
# Processed frame 417 of 3204
# Processed frame 418 of 3204
# Processed frame 419 of 3204
# Processed frame 420 of 3204
# Processed frame 421 of 3204
# Processed frame 422 of 3204
# Processed frame 423 of 3204
# Processed frame 424 of 3204
# Processed frame 425 of 3204
# Processed frame 426 of 3204
# Processed frame 427 of 3204
# Processed frame 428 of 3204
# Processed frame 429 of 3204
# Processed frame 430 of 3204
# Processed frame 431 of 3204
# Processed frame 432 of 3204
# Processed frame 433 of 3204
# Processed frame 434 of 3204
# Processed frame 435 of 3204
# Processed frame 436 of 3204
# Processed frame 437 of 3204
# Processed frame 438 of 3204
# Processed frame 439 of 3204
# Processed frame 440 of 3204
# Processed frame 441 of 3204
# Processed frame 442 of 3204
# Processed frame 443 of 3204
# Processed frame 444 of 3204
# Processed frame 445 of 3204
# Processed frame 446 of 3204
# Processed frame 447 of 3204
# Processed frame 448 of 3204
# Processed frame 449 of 3204
# Processed frame 450 of 3204
# Processed frame 451 of 3204
# Processed frame 452 of 3204
# Processed frame 453 of 3204
# Processed frame 454 of 3204
# Processed frame 455 of 3204
# Processed frame 456 of 3204
# Processed frame 457 of 3204
# Processed frame 458 of 3204
# Processed frame 459 of 3204
# Processed frame 460 of 3204
# Processed frame 461 of 3204
# Processed frame 462 of 3204
# Processed frame 463 of 3204
# Processed frame 464 of 3204
# Processed frame 465 of 3204
# Processed frame 466 of 3204
# Processed frame 467 of 3204
# Processed frame 468 of 3204
# Processed frame 469 of 3204
# Processed frame 470 of 3204
# Processed frame 471 of 3204
# Processed frame 472 of 3204
# Processed frame 473 of 3204
# Processed frame 474 of 3204
# Processed frame 475 of 3204
# Processed frame 476 of 3204
# Processed frame 477 of 3204
# Processed frame 478 of 3204
# Processed frame 479 of 3204
# Processed frame 480 of 3204
# Processed frame 481 of 3204
# Processed frame 482 of 3204
# Processed frame 483 of 3204
# Processed frame 484 of 3204
# Processed frame 485 of 3204
# Processed frame 486 of 3204
# Processed frame 487 of 3204
# Processed frame 488 of 3204
# Processed frame 489 of 3204
# Processed frame 490 of 3204
# Processed frame 491 of 3204
# Processed frame 492 of 3204
# Processed frame 493 of 3204
# Processed frame 494 of 3204
# Processed frame 495 of 3204
# Processed frame 496 of 3204
# Processed frame 497 of 3204
# Processed frame 498 of 3204
# Processed frame 499 of 3204
# Processed frame 500 of 3204
# Processed frame 501 of 3204
# Processed frame 502 of 3204
# Processed frame 503 of 3204
# Processed frame 504 of 3204
# Processed frame 505 of 3204
# Processed frame 506 of 3204
# Processed frame 507 of 3204
# Processed frame 508 of 3204
# Processed frame 509 of 3204
# Processed frame 510 of 3204
# Processed frame 511 of 3204
# Processed frame 512 of 3204
# Processed frame 513 of 3204
# Processed frame 514 of 3204
# Processed frame 515 of 3204
# Processed frame 516 of 3204
# Processed frame 517 of 3204
# Processed frame 518 of 3204
# Processed frame 519 of 3204
# Processed frame 520 of 3204
# Processed frame 521 of 3204
# Processed frame 522 of 3204
# Processed frame 523 of 3204
# Processed frame 524 of 3204
# Processed frame 525 of 3204
# Processed frame 526 of 3204
# Processed frame 527 of 3204
# Processed frame 528 of 3204
# Processed frame 529 of 3204
# Processed frame 530 of 3204
# Processed frame 531 of 3204
# Processed frame 532 of 3204
# Processed frame 533 of 3204
# Processed frame 534 of 3204
# Processed frame 535 of 3204
# Processed frame 536 of 3204
# Processed frame 537 of 3204
# Processed frame 538 of 3204
# Processed frame 539 of 3204
# Processed frame 540 of 3204
# Processed frame 541 of 3204
# Processed frame 542 of 3204
# Processed frame 543 of 3204
# Processed frame 544 of 3204
# Processed frame 545 of 3204
# Processed frame 546 of 3204
# Processed frame 547 of 3204
# Processed frame 548 of 3204
# Processed frame 549 of 3204
# Processed frame 550 of 3204
# Processed frame 551 of 3204
# Processed frame 552 of 3204
# Processed frame 553 of 3204
# Processed frame 554 of 3204
# Processed frame 555 of 3204
# Processed frame 556 of 3204
# Processed frame 557 of 3204
# Processed frame 558 of 3204
# Processed frame 559 of 3204
# Processed frame 560 of 3204
# Processed frame 561 of 3204
# Processed frame 562 of 3204
# Processed frame 563 of 3204
# Processed frame 564 of 3204
# Processed frame 565 of 3204
# Processed frame 566 of 3204
# Processed frame 567 of 3204
# Processed frame 568 of 3204
# Processed frame 569 of 3204
# Processed frame 570 of 3204
# Processed frame 571 of 3204
# Processed frame 572 of 3204
# Processed frame 573 of 3204
# Processed frame 574 of 3204
# Processed frame 575 of 3204
# Processed frame 576 of 3204
# Processed frame 577 of 3204
# Processed frame 578 of 3204
# Processed frame 579 of 3204
# Processed frame 580 of 3204
# Processed frame 581 of 3204
# Processed frame 582 of 3204
# Processed frame 583 of 3204
# Processed frame 584 of 3204
# Processed frame 585 of 3204
# Processed frame 586 of 3204
# Processed frame 587 of 3204
# Processed frame 588 of 3204
# Processed frame 589 of 3204
# Processed frame 590 of 3204
# Processed frame 591 of 3204
# Processed frame 592 of 3204
# Processed frame 593 of 3204
# Processed frame 594 of 3204
# Processed frame 595 of 3204
# Processed frame 596 of 3204
# Processed frame 597 of 3204
# Processed frame 598 of 3204
# Processed frame 599 of 3204
# Processed frame 600 of 3204
# Processed frame 601 of 3204
# Processed frame 602 of 3204
# Processed frame 603 of 3204
# Processed frame 604 of 3204
# Processed frame 605 of 3204
# Processed frame 606 of 3204
# Processed frame 607 of 3204
# Processed frame 608 of 3204
# Processed frame 609 of 3204
# Processed frame 610 of 3204
# Processed frame 611 of 3204
# Processed frame 612 of 3204
# Processed frame 613 of 3204
# Processed frame 614 of 3204
# Processed frame 615 of 3204
# Processed frame 616 of 3204
# Processed frame 617 of 3204
# Processed frame 618 of 3204
# Processed frame 619 of 3204
# Processed frame 620 of 3204
# Processed frame 621 of 3204
# Processed frame 622 of 3204
# Processed frame 623 of 3204
# Processed frame 624 of 3204
# Processed frame 625 of 3204
# Processed frame 626 of 3204
# Processed frame 627 of 3204
# Processed frame 628 of 3204
# Processed frame 629 of 3204
# Processed frame 630 of 3204
# Processed frame 631 of 3204
# Processed frame 632 of 3204
# Processed frame 633 of 3204
# Processed frame 634 of 3204
# Processed frame 635 of 3204
# Processed frame 636 of 3204
# Processed frame 637 of 3204
# Processed frame 638 of 3204
# Processed frame 639 of 3204
# Processed frame 640 of 3204
# Processed frame 641 of 3204
# Processed frame 642 of 3204
# Processed frame 643 of 3204
# Processed frame 644 of 3204
# Processed frame 645 of 3204
# Processed frame 646 of 3204
# Processed frame 647 of 3204
# Processed frame 648 of 3204
# Processed frame 649 of 3204
# Processed frame 650 of 3204
# Processed frame 651 of 3204
# Processed frame 652 of 3204
# Processed frame 653 of 3204
# Processed frame 654 of 3204
# Processed frame 655 of 3204
# Processed frame 656 of 3204
# Processed frame 657 of 3204
# Processed frame 658 of 3204
# Processed frame 659 of 3204
# Processed frame 660 of 3204
# Processed frame 661 of 3204
# Processed frame 662 of 3204
# Processed frame 663 of 3204
# Processed frame 664 of 3204
# Processed frame 665 of 3204
# Processed frame 666 of 3204
# Processed frame 667 of 3204
# Processed frame 668 of 3204
# Processed frame 669 of 3204
# Processed frame 670 of 3204
# Processed frame 671 of 3204
# Processed frame 672 of 3204
# Processed frame 673 of 3204
# Processed frame 674 of 3204
# Processed frame 675 of 3204
# Processed frame 676 of 3204
# Processed frame 677 of 3204
# Processed frame 678 of 3204
# Processed frame 679 of 3204
# Processed frame 680 of 3204
# Processed frame 681 of 3204
# Processed frame 682 of 3204
# Processed frame 683 of 3204
# Processed frame 684 of 3204
# Processed frame 685 of 3204
# Processed frame 686 of 3204
# Processed frame 687 of 3204
# Processed frame 688 of 3204
# Processed frame 689 of 3204
# Processed frame 690 of 3204
# Processed frame 691 of 3204
# Processed frame 692 of 3204
# Processed frame 693 of 3204
# Processed frame 694 of 3204
# Processed frame 695 of 3204
# Processed frame 696 of 3204
# Processed frame 697 of 3204
# Processed frame 698 of 3204
# Processed frame 699 of 3204
# Processed frame 700 of 3204
# Processed frame 701 of 3204
# Processed frame 702 of 3204
# Processed frame 703 of 3204
# Processed frame 704 of 3204
# Processed frame 705 of 3204
# Processed frame 706 of 3204
# Processed frame 707 of 3204
# Processed frame 708 of 3204
# Processed frame 709 of 3204
# Processed frame 710 of 3204
# Processed frame 711 of 3204
# Processed frame 712 of 3204
# Processed frame 713 of 3204
# Processed frame 714 of 3204
# Processed frame 715 of 3204
# Processed frame 716 of 3204
# Processed frame 717 of 3204
# Processed frame 718 of 3204
# Processed frame 719 of 3204
# Processed frame 720 of 3204
# Processed frame 721 of 3204
# Processed frame 722 of 3204
# Processed frame 723 of 3204
# Processed frame 724 of 3204
# Processed frame 725 of 3204
# Processed frame 726 of 3204
# Processed frame 727 of 3204
# Processed frame 728 of 3204
# Processed frame 729 of 3204
# Processed frame 730 of 3204
# Processed frame 731 of 3204
# Processed frame 732 of 3204
# Processed frame 733 of 3204
# Processed frame 734 of 3204
# Processed frame 735 of 3204
# Processed frame 736 of 3204
# Processed frame 737 of 3204
# Processed frame 738 of 3204
# Processed frame 739 of 3204
# Processed frame 740 of 3204
# Processed frame 741 of 3204
# Processed frame 742 of 3204
# Processed frame 743 of 3204
# Processed frame 744 of 3204
# Processed frame 745 of 3204
# Processed frame 746 of 3204
# Processed frame 747 of 3204
# Processed frame 748 of 3204
# Processed frame 749 of 3204
# Processed frame 750 of 3204
# Processed frame 751 of 3204
# Processed frame 752 of 3204
# Processed frame 753 of 3204
# Processed frame 754 of 3204
# Processed frame 755 of 3204
# Processed frame 756 of 3204
# Processed frame 757 of 3204
# Processed frame 758 of 3204
# Processed frame 759 of 3204
# Processed frame 760 of 3204
# Processed frame 761 of 3204
# Processed frame 762 of 3204
# Processed frame 763 of 3204
# Processed frame 764 of 3204
# Processed frame 765 of 3204
# Processed frame 766 of 3204
# Processed frame 767 of 3204
# Processed frame 768 of 3204
# Processed frame 769 of 3204
# Processed frame 770 of 3204
# Processed frame 771 of 3204
# Processed frame 772 of 3204
# Processed frame 773 of 3204
# Processed frame 774 of 3204
# Processed frame 775 of 3204
# Processed frame 776 of 3204
# Processed frame 777 of 3204
# Processed frame 778 of 3204
# Processed frame 779 of 3204
# Processed frame 780 of 3204
# Processed frame 781 of 3204
# Processed frame 782 of 3204
# Processed frame 783 of 3204
# Processed frame 784 of 3204
# Processed frame 785 of 3204
# Processed frame 786 of 3204
# Processed frame 787 of 3204
# Processed frame 788 of 3204
# Processed frame 789 of 3204
# Processed frame 790 of 3204
# Processed frame 791 of 3204
# Processed frame 792 of 3204
# Processed frame 793 of 3204
# Processed frame 794 of 3204
# Processed frame 795 of 3204
# Processed frame 796 of 3204
# Processed frame 797 of 3204
# Processed frame 798 of 3204
# Processed frame 799 of 3204
# Processed frame 800 of 3204
# Processed frame 801 of 3204
# Processed frame 802 of 3204
# Processed frame 803 of 3204
# Processed frame 804 of 3204
# Processed frame 805 of 3204
# Processed frame 806 of 3204
# Processed frame 807 of 3204
# Processed frame 808 of 3204
# Processed frame 809 of 3204
# Processed frame 810 of 3204
# Processed frame 811 of 3204
# Processed frame 812 of 3204
# Processed frame 813 of 3204
# Processed frame 814 of 3204
# Processed frame 815 of 3204
# Processed frame 816 of 3204
# Processed frame 817 of 3204
# Processed frame 818 of 3204
# Processed frame 819 of 3204
# Processed frame 820 of 3204
# Processed frame 821 of 3204
# Processed frame 822 of 3204
# Processed frame 823 of 3204
# Processed frame 824 of 3204
# Processed frame 825 of 3204
# Processed frame 826 of 3204
# Processed frame 827 of 3204
# Processed frame 828 of 3204
# Processed frame 829 of 3204
# Processed frame 830 of 3204
# Processed frame 831 of 3204
# Processed frame 832 of 3204
# Processed frame 833 of 3204
# Processed frame 834 of 3204
# Processed frame 835 of 3204
# Processed frame 836 of 3204
# Processed frame 837 of 3204
# Processed frame 838 of 3204
# Processed frame 839 of 3204
# Processed frame 840 of 3204
# Processed frame 841 of 3204
# Processed frame 842 of 3204
# Processed frame 843 of 3204
# Processed frame 844 of 3204
# Processed frame 845 of 3204
# Processed frame 846 of 3204
# Processed frame 847 of 3204
# Processed frame 848 of 3204
# Processed frame 849 of 3204
# Processed frame 850 of 3204
# Processed frame 851 of 3204
# Processed frame 852 of 3204
# Processed frame 853 of 3204
# Processed frame 854 of 3204
# Processed frame 855 of 3204
# Processed frame 856 of 3204
# Processed frame 857 of 3204
# Processed frame 858 of 3204
# Processed frame 859 of 3204
# Processed frame 860 of 3204
# Processed frame 861 of 3204
# Processed frame 862 of 3204
# Processed frame 863 of 3204
# Processed frame 864 of 3204
# Processed frame 865 of 3204
# Processed frame 866 of 3204
# Processed frame 867 of 3204
# Processed frame 868 of 3204
# Processed frame 869 of 3204
# Processed frame 870 of 3204
# Processed frame 871 of 3204
# Processed frame 872 of 3204
# Processed frame 873 of 3204
# Processed frame 874 of 3204
# Processed frame 875 of 3204
# Processed frame 876 of 3204
# Processed frame 877 of 3204
# Processed frame 878 of 3204
# Processed frame 879 of 3204
# Processed frame 880 of 3204
# Processed frame 881 of 3204
# Processed frame 882 of 3204
# Processed frame 883 of 3204
# Processed frame 884 of 3204
# Processed frame 885 of 3204
# Processed frame 886 of 3204
# Processed frame 887 of 3204
# Processed frame 888 of 3204
# Processed frame 889 of 3204
# Processed frame 890 of 3204
# Processed frame 891 of 3204
# Processed frame 892 of 3204
# Processed frame 893 of 3204
# Processed frame 894 of 3204
# Processed frame 895 of 3204
# Processed frame 896 of 3204
# Processed frame 897 of 3204
# Processed frame 898 of 3204
# Processed frame 899 of 3204
# Processed frame 900 of 3204
# Processed frame 901 of 3204
# Processed frame 902 of 3204
# Processed frame 903 of 3204
# Processed frame 904 of 3204
# Processed frame 905 of 3204
# Processed frame 906 of 3204
# Processed frame 907 of 3204
# Processed frame 908 of 3204
# Processed frame 909 of 3204
# Processed frame 910 of 3204
# Processed frame 911 of 3204
# Processed frame 912 of 3204
# Processed frame 913 of 3204
# Processed frame 914 of 3204
# Processed frame 915 of 3204
# Processed frame 916 of 3204
# Processed frame 917 of 3204
# Processed frame 918 of 3204
# Processed frame 919 of 3204
# Processed frame 920 of 3204
# Processed frame 921 of 3204
# Processed frame 922 of 3204
# Processed frame 923 of 3204
# Processed frame 924 of 3204
# Processed frame 925 of 3204
# Processed frame 926 of 3204
# Processed frame 927 of 3204
# Processed frame 928 of 3204
# Processed frame 929 of 3204
# Processed frame 930 of 3204
# Processed frame 931 of 3204
# Processed frame 932 of 3204
# Processed frame 933 of 3204
# Processed frame 934 of 3204
# Processed frame 935 of 3204
# Processed frame 936 of 3204
# Processed frame 937 of 3204
# Processed frame 938 of 3204
# Processed frame 939 of 3204
# Processed frame 940 of 3204
# Processed frame 941 of 3204
# Processed frame 942 of 3204
# Processed frame 943 of 3204
# Processed frame 944 of 3204
# Processed frame 945 of 3204
# Processed frame 946 of 3204
# Processed frame 947 of 3204
# Processed frame 948 of 3204
# Processed frame 949 of 3204
# Processed frame 950 of 3204
# Processed frame 951 of 3204
# Processed frame 952 of 3204
# Processed frame 953 of 3204
# Processed frame 954 of 3204
# Processed frame 955 of 3204
# Processed frame 956 of 3204
# Processed frame 957 of 3204
# Processed frame 958 of 3204
# Processed frame 959 of 3204
# Processed frame 960 of 3204
# Processed frame 961 of 3204
# Processed frame 962 of 3204
# Processed frame 963 of 3204
# Processed frame 964 of 3204
# Processed frame 965 of 3204
# Processed frame 966 of 3204
# Processed frame 967 of 3204
# Processed frame 968 of 3204
# Processed frame 969 of 3204
# Processed frame 970 of 3204
# Processed frame 971 of 3204
# Processed frame 972 of 3204
# Processed frame 973 of 3204
# Processed frame 974 of 3204
# Processed frame 975 of 3204
# Processed frame 976 of 3204
# Processed frame 977 of 3204
# Processed frame 978 of 3204
# Processed frame 979 of 3204
# Processed frame 980 of 3204
# Processed frame 981 of 3204
# Processed frame 982 of 3204
# Processed frame 983 of 3204
# Processed frame 984 of 3204
# Processed frame 985 of 3204
# Processed frame 986 of 3204
# Processed frame 987 of 3204
# Processed frame 988 of 3204
# Processed frame 989 of 3204
# Processed frame 990 of 3204
# Processed frame 991 of 3204
# Processed frame 992 of 3204
# Processed frame 993 of 3204
# Processed frame 994 of 3204
# Processed frame 995 of 3204
# Processed frame 996 of 3204
# Processed frame 997 of 3204
# Processed frame 998 of 3204
# Processed frame 999 of 3204
# Processed frame 1000 of 3204
# Finished writing /scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/2024-11-12-15-23-47_channel1_1.tiff
# Writing frames 1000 to 1999 to /scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/2024-11-12-15-23-47_channel1_2.tiff
# Processed frame 1001 of 3204
# Processed frame 1002 of 3204
# Processed frame 1003 of 3204
# Processed frame 1004 of 3204
# Processed frame 1005 of 3204
# Processed frame 1006 of 3204
# Processed frame 1007 of 3204
# Processed frame 1008 of 3204
# Processed frame 1009 of 3204
# Processed frame 1010 of 3204
# Processed frame 1011 of 3204
# Processed frame 1012 of 3204
# Processed frame 1013 of 3204
# Processed frame 1014 of 3204
# Processed frame 1015 of 3204
# Processed frame 1016 of 3204
# Processed frame 1017 of 3204
# Processed frame 1018 of 3204
# Processed frame 1019 of 3204
# Processed frame 1020 of 3204
# Processed frame 1021 of 3204
# Processed frame 1022 of 3204
# Processed frame 1023 of 3204
# Processed frame 1024 of 3204
# Processed frame 1025 of 3204
# Processed frame 1026 of 3204
# Processed frame 1027 of 3204
# Processed frame 1028 of 3204
# Processed frame 1029 of 3204
# Processed frame 1030 of 3204
# Processed frame 1031 of 3204
# Processed frame 1032 of 3204
# Processed frame 1033 of 3204
# Processed frame 1034 of 3204
# Processed frame 1035 of 3204
# Processed frame 1036 of 3204
# Processed frame 1037 of 3204
# Processed frame 1038 of 3204
# Processed frame 1039 of 3204
# Processed frame 1040 of 3204
# Processed frame 1041 of 3204
# Processed frame 1042 of 3204
# Processed frame 1043 of 3204
# Processed frame 1044 of 3204
# Processed frame 1045 of 3204
# Processed frame 1046 of 3204
# Processed frame 1047 of 3204
# Processed frame 1048 of 3204
# Processed frame 1049 of 3204
# Processed frame 1050 of 3204
# Processed frame 1051 of 3204
# Processed frame 1052 of 3204
# Processed frame 1053 of 3204
# Processed frame 1054 of 3204
# Processed frame 1055 of 3204
# Processed frame 1056 of 3204
# Processed frame 1057 of 3204
# Processed frame 1058 of 3204
# Processed frame 1059 of 3204
# Processed frame 1060 of 3204
# Processed frame 1061 of 3204
# Processed frame 1062 of 3204
# Processed frame 1063 of 3204
# Processed frame 1064 of 3204
# Processed frame 1065 of 3204
# Processed frame 1066 of 3204
# Processed frame 1067 of 3204
# Processed frame 1068 of 3204
# Processed frame 1069 of 3204
# Processed frame 1070 of 3204
# Processed frame 1071 of 3204
# Processed frame 1072 of 3204
# Processed frame 1073 of 3204
# Processed frame 1074 of 3204
# Processed frame 1075 of 3204
# Processed frame 1076 of 3204
# Processed frame 1077 of 3204
# Processed frame 1078 of 3204
# Processed frame 1079 of 3204
# Processed frame 1080 of 3204
# Processed frame 1081 of 3204
# Processed frame 1082 of 3204
# Processed frame 1083 of 3204
# Processed frame 1084 of 3204
# Processed frame 1085 of 3204
# Processed frame 1086 of 3204
# Processed frame 1087 of 3204
# Processed frame 1088 of 3204
# Processed frame 1089 of 3204
# Processed frame 1090 of 3204
# Processed frame 1091 of 3204
# Processed frame 1092 of 3204
# Processed frame 1093 of 3204
# Processed frame 1094 of 3204
# Processed frame 1095 of 3204
# Processed frame 1096 of 3204
# Processed frame 1097 of 3204
# Processed frame 1098 of 3204
# Processed frame 1099 of 3204
# Processed frame 1100 of 3204
# Processed frame 1101 of 3204
# Processed frame 1102 of 3204
# Processed frame 1103 of 3204
# Processed frame 1104 of 3204
# Processed frame 1105 of 3204
# Processed frame 1106 of 3204
# Processed frame 1107 of 3204
# Processed frame 1108 of 3204
# Processed frame 1109 of 3204
# Processed frame 1110 of 3204
# Processed frame 1111 of 3204
# Processed frame 1112 of 3204
# Processed frame 1113 of 3204
# Processed frame 1114 of 3204
# Processed frame 1115 of 3204
# Processed frame 1116 of 3204
# Processed frame 1117 of 3204
# Processed frame 1118 of 3204
# Processed frame 1119 of 3204
# Processed frame 1120 of 3204
# Processed frame 1121 of 3204
# Processed frame 1122 of 3204
# Processed frame 1123 of 3204
# Processed frame 1124 of 3204
# Processed frame 1125 of 3204
# Processed frame 1126 of 3204
# Processed frame 1127 of 3204
# Processed frame 1128 of 3204
# Processed frame 1129 of 3204
# Processed frame 1130 of 3204
# Processed frame 1131 of 3204
# Processed frame 1132 of 3204
# Processed frame 1133 of 3204
# Processed frame 1134 of 3204
# Processed frame 1135 of 3204
# Processed frame 1136 of 3204
# Processed frame 1137 of 3204
# Processed frame 1138 of 3204
# Processed frame 1139 of 3204
# Processed frame 1140 of 3204
# Processed frame 1141 of 3204
# Processed frame 1142 of 3204
# Processed frame 1143 of 3204
# Processed frame 1144 of 3204
# Processed frame 1145 of 3204
# Processed frame 1146 of 3204
# Processed frame 1147 of 3204
# Processed frame 1148 of 3204
# Processed frame 1149 of 3204
# Processed frame 1150 of 3204
# Processed frame 1151 of 3204
# Processed frame 1152 of 3204
# Processed frame 1153 of 3204
# Processed frame 1154 of 3204
# Processed frame 1155 of 3204
# Processed frame 1156 of 3204
# Processed frame 1157 of 3204
# Processed frame 1158 of 3204
# Processed frame 1159 of 3204
# Processed frame 1160 of 3204
# Processed frame 1161 of 3204
# Processed frame 1162 of 3204
# Processed frame 1163 of 3204
# Processed frame 1164 of 3204
# Processed frame 1165 of 3204
# Processed frame 1166 of 3204
# Processed frame 1167 of 3204
# Processed frame 1168 of 3204
# Processed frame 1169 of 3204
# Processed frame 1170 of 3204
# Processed frame 1171 of 3204
# Processed frame 1172 of 3204
# Processed frame 1173 of 3204
# Processed frame 1174 of 3204
# Processed frame 1175 of 3204
# Processed frame 1176 of 3204
# Processed frame 1177 of 3204
# Processed frame 1178 of 3204
# Processed frame 1179 of 3204
# Processed frame 1180 of 3204
# Processed frame 1181 of 3204
# Processed frame 1182 of 3204
# Processed frame 1183 of 3204
# Processed frame 1184 of 3204
# Processed frame 1185 of 3204
# Processed frame 1186 of 3204
# Processed frame 1187 of 3204
# Processed frame 1188 of 3204
# Processed frame 1189 of 3204
# Processed frame 1190 of 3204
# Processed frame 1191 of 3204
# Processed frame 1192 of 3204
# Processed frame 1193 of 3204
# Processed frame 1194 of 3204
# Processed frame 1195 of 3204
# Processed frame 1196 of 3204
# Processed frame 1197 of 3204
# Processed frame 1198 of 3204
# Processed frame 1199 of 3204
# Processed frame 1200 of 3204
# Processed frame 1201 of 3204
# Processed frame 1202 of 3204
# Processed frame 1203 of 3204
# Processed frame 1204 of 3204
# Processed frame 1205 of 3204
# Processed frame 1206 of 3204
# Processed frame 1207 of 3204
# Processed frame 1208 of 3204
# Processed frame 1209 of 3204
# Processed frame 1210 of 3204
# Processed frame 1211 of 3204
# Processed frame 1212 of 3204
# Processed frame 1213 of 3204
# Processed frame 1214 of 3204
# Processed frame 1215 of 3204
# Processed frame 1216 of 3204
# Processed frame 1217 of 3204
# Processed frame 1218 of 3204
# Processed frame 1219 of 3204
# Processed frame 1220 of 3204
# Processed frame 1221 of 3204
# Processed frame 1222 of 3204
# Processed frame 1223 of 3204
# Processed frame 1224 of 3204
# Processed frame 1225 of 3204
# Processed frame 1226 of 3204
# Processed frame 1227 of 3204
# Processed frame 1228 of 3204
# Processed frame 1229 of 3204
# Processed frame 1230 of 3204
# Processed frame 1231 of 3204
# Processed frame 1232 of 3204
# Processed frame 1233 of 3204
# Processed frame 1234 of 3204
# Processed frame 1235 of 3204
# Processed frame 1236 of 3204
# Processed frame 1237 of 3204
# Processed frame 1238 of 3204
# Processed frame 1239 of 3204
# Processed frame 1240 of 3204
# Processed frame 1241 of 3204
# Processed frame 1242 of 3204
# Processed frame 1243 of 3204
# Processed frame 1244 of 3204
# Processed frame 1245 of 3204
# Processed frame 1246 of 3204
# Processed frame 1247 of 3204
# Processed frame 1248 of 3204
# Processed frame 1249 of 3204
# Processed frame 1250 of 3204
# Processed frame 1251 of 3204
# Processed frame 1252 of 3204
# Processed frame 1253 of 3204
# Processed frame 1254 of 3204
# Processed frame 1255 of 3204
# Processed frame 1256 of 3204
# Processed frame 1257 of 3204
# Processed frame 1258 of 3204
# Processed frame 1259 of 3204
# Processed frame 1260 of 3204
# Processed frame 1261 of 3204
# Processed frame 1262 of 3204
# Processed frame 1263 of 3204
# Processed frame 1264 of 3204
# Processed frame 1265 of 3204
# Processed frame 1266 of 3204
# Processed frame 1267 of 3204
# Processed frame 1268 of 3204
# Processed frame 1269 of 3204
# Processed frame 1270 of 3204
# Processed frame 1271 of 3204
# Processed frame 1272 of 3204
# Processed frame 1273 of 3204
# Processed frame 1274 of 3204
# Processed frame 1275 of 3204
# Processed frame 1276 of 3204
# Processed frame 1277 of 3204
# Processed frame 1278 of 3204
# Processed frame 1279 of 3204
# Processed frame 1280 of 3204
# Processed frame 1281 of 3204
# Processed frame 1282 of 3204
# Processed frame 1283 of 3204
# Processed frame 1284 of 3204
# Processed frame 1285 of 3204
# Processed frame 1286 of 3204
# Processed frame 1287 of 3204
# Processed frame 1288 of 3204
# Processed frame 1289 of 3204
# Processed frame 1290 of 3204
# Processed frame 1291 of 3204
# Processed frame 1292 of 3204
# Processed frame 1293 of 3204
# Processed frame 1294 of 3204
# Processed frame 1295 of 3204
# Processed frame 1296 of 3204
# Processed frame 1297 of 3204
# Processed frame 1298 of 3204
# Processed frame 1299 of 3204
# Processed frame 1300 of 3204
# Processed frame 1301 of 3204
# Processed frame 1302 of 3204
# Processed frame 1303 of 3204
# Processed frame 1304 of 3204
# Processed frame 1305 of 3204
# Processed frame 1306 of 3204
# Processed frame 1307 of 3204
# Processed frame 1308 of 3204
# Processed frame 1309 of 3204
# Processed frame 1310 of 3204
# Processed frame 1311 of 3204
# Processed frame 1312 of 3204
# Processed frame 1313 of 3204
# Processed frame 1314 of 3204
# Processed frame 1315 of 3204
# Processed frame 1316 of 3204
# Processed frame 1317 of 3204
# Processed frame 1318 of 3204
# Processed frame 1319 of 3204
# Processed frame 1320 of 3204
# Processed frame 1321 of 3204
# Processed frame 1322 of 3204
# Processed frame 1323 of 3204
# Processed frame 1324 of 3204
# Processed frame 1325 of 3204
# Processed frame 1326 of 3204
# Processed frame 1327 of 3204
# Processed frame 1328 of 3204
# Processed frame 1329 of 3204
# Processed frame 1330 of 3204
# Processed frame 1331 of 3204
# Processed frame 1332 of 3204
# Processed frame 1333 of 3204
# Processed frame 1334 of 3204
# Processed frame 1335 of 3204
# Processed frame 1336 of 3204
# Processed frame 1337 of 3204
# Processed frame 1338 of 3204
# Processed frame 1339 of 3204
# Processed frame 1340 of 3204
# Processed frame 1341 of 3204
# Processed frame 1342 of 3204
# Processed frame 1343 of 3204
# Processed frame 1344 of 3204
# Processed frame 1345 of 3204
# Processed frame 1346 of 3204
# Processed frame 1347 of 3204
# Processed frame 1348 of 3204
# Processed frame 1349 of 3204
# Processed frame 1350 of 3204
# Processed frame 1351 of 3204
# Processed frame 1352 of 3204
# Processed frame 1353 of 3204
# Processed frame 1354 of 3204
# Processed frame 1355 of 3204
# Processed frame 1356 of 3204
# Processed frame 1357 of 3204
# Processed frame 1358 of 3204
# Processed frame 1359 of 3204
# Processed frame 1360 of 3204
# Processed frame 1361 of 3204
# Processed frame 1362 of 3204
# Processed frame 1363 of 3204
# Processed frame 1364 of 3204
# Processed frame 1365 of 3204
# Processed frame 1366 of 3204
# Processed frame 1367 of 3204
# Processed frame 1368 of 3204
# Processed frame 1369 of 3204
# Processed frame 1370 of 3204
# Processed frame 1371 of 3204
# Processed frame 1372 of 3204
# Processed frame 1373 of 3204
# Processed frame 1374 of 3204
# Processed frame 1375 of 3204
# Processed frame 1376 of 3204
# Processed frame 1377 of 3204
# Processed frame 1378 of 3204
# Processed frame 1379 of 3204
# Processed frame 1380 of 3204
# Processed frame 1381 of 3204
# Processed frame 1382 of 3204
# Processed frame 1383 of 3204
# Processed frame 1384 of 3204
# Processed frame 1385 of 3204
# Processed frame 1386 of 3204
# Processed frame 1387 of 3204
# Processed frame 1388 of 3204
# Processed frame 1389 of 3204
# Processed frame 1390 of 3204
# Processed frame 1391 of 3204
# Processed frame 1392 of 3204
# Processed frame 1393 of 3204
# Processed frame 1394 of 3204
# Processed frame 1395 of 3204
# Processed frame 1396 of 3204
# Processed frame 1397 of 3204
# Processed frame 1398 of 3204
# Processed frame 1399 of 3204
# Processed frame 1400 of 3204
# Processed frame 1401 of 3204
# Processed frame 1402 of 3204
# Processed frame 1403 of 3204
# Processed frame 1404 of 3204
# Processed frame 1405 of 3204
# Processed frame 1406 of 3204
# Processed frame 1407 of 3204
# Processed frame 1408 of 3204
# Processed frame 1409 of 3204
# Processed frame 1410 of 3204
# Processed frame 1411 of 3204
# Processed frame 1412 of 3204
# Processed frame 1413 of 3204
# Processed frame 1414 of 3204
# Processed frame 1415 of 3204
# Processed frame 1416 of 3204
# Processed frame 1417 of 3204
# Processed frame 1418 of 3204
# Processed frame 1419 of 3204
# Processed frame 1420 of 3204
# Processed frame 1421 of 3204
# Processed frame 1422 of 3204
# Processed frame 1423 of 3204
# Processed frame 1424 of 3204
# Processed frame 1425 of 3204
# Processed frame 1426 of 3204
# Processed frame 1427 of 3204
# Processed frame 1428 of 3204
# Processed frame 1429 of 3204
# Processed frame 1430 of 3204
# Processed frame 1431 of 3204
# Processed frame 1432 of 3204
# Processed frame 1433 of 3204
# Processed frame 1434 of 3204
# Processed frame 1435 of 3204
# Processed frame 1436 of 3204
# Processed frame 1437 of 3204
# Processed frame 1438 of 3204
# Processed frame 1439 of 3204
# Processed frame 1440 of 3204
# Processed frame 1441 of 3204
# Processed frame 1442 of 3204
# Processed frame 1443 of 3204
# Processed frame 1444 of 3204
# Processed frame 1445 of 3204
# Processed frame 1446 of 3204
# Processed frame 1447 of 3204
# Processed frame 1448 of 3204
# Processed frame 1449 of 3204
# Processed frame 1450 of 3204
# Processed frame 1451 of 3204
# Processed frame 1452 of 3204
# Processed frame 1453 of 3204
# Processed frame 1454 of 3204
# Processed frame 1455 of 3204
# Processed frame 1456 of 3204
# Processed frame 1457 of 3204
# Processed frame 1458 of 3204
# Processed frame 1459 of 3204
# Processed frame 1460 of 3204
# Processed frame 1461 of 3204
# Processed frame 1462 of 3204
# Processed frame 1463 of 3204
# Processed frame 1464 of 3204
# Processed frame 1465 of 3204
# Processed frame 1466 of 3204
# Processed frame 1467 of 3204
# Processed frame 1468 of 3204
# Processed frame 1469 of 3204
# Processed frame 1470 of 3204
# Processed frame 1471 of 3204
# Processed frame 1472 of 3204
# Processed frame 1473 of 3204
# Processed frame 1474 of 3204
# Processed frame 1475 of 3204
# Processed frame 1476 of 3204
# Processed frame 1477 of 3204
# Processed frame 1478 of 3204
# Processed frame 1479 of 3204
# Processed frame 1480 of 3204
# Processed frame 1481 of 3204
# Processed frame 1482 of 3204
# Processed frame 1483 of 3204
# Processed frame 1484 of 3204
# Processed frame 1485 of 3204
# Processed frame 1486 of 3204
# Processed frame 1487 of 3204
# Processed frame 1488 of 3204
# Processed frame 1489 of 3204
# Processed frame 1490 of 3204
# Processed frame 1491 of 3204
# Processed frame 1492 of 3204
# Processed frame 1493 of 3204
# Processed frame 1494 of 3204
# Processed frame 1495 of 3204
# Processed frame 1496 of 3204
# Processed frame 1497 of 3204
# Processed frame 1498 of 3204
# Processed frame 1499 of 3204
# Processed frame 1500 of 3204
# Processed frame 1501 of 3204
# Processed frame 1502 of 3204
# Processed frame 1503 of 3204
# Processed frame 1504 of 3204
# Processed frame 1505 of 3204
# Processed frame 1506 of 3204
# Processed frame 1507 of 3204
# Processed frame 1508 of 3204
# Processed frame 1509 of 3204
# Processed frame 1510 of 3204
# Processed frame 1511 of 3204
# Processed frame 1512 of 3204
# Processed frame 1513 of 3204
# Processed frame 1514 of 3204
# Processed frame 1515 of 3204
# Processed frame 1516 of 3204
# Processed frame 1517 of 3204
# Processed frame 1518 of 3204
# Processed frame 1519 of 3204
# Processed frame 1520 of 3204
# Processed frame 1521 of 3204
# Processed frame 1522 of 3204
# Processed frame 1523 of 3204
# Processed frame 1524 of 3204
# Processed frame 1525 of 3204
# Processed frame 1526 of 3204
# Processed frame 1527 of 3204
# Processed frame 1528 of 3204
# Processed frame 1529 of 3204
# Processed frame 1530 of 3204
# Processed frame 1531 of 3204
# Processed frame 1532 of 3204
# Processed frame 1533 of 3204
# Processed frame 1534 of 3204
# Processed frame 1535 of 3204
# Processed frame 1536 of 3204
# Processed frame 1537 of 3204
# Processed frame 1538 of 3204
# Processed frame 1539 of 3204
# Processed frame 1540 of 3204
# Processed frame 1541 of 3204
# Processed frame 1542 of 3204
# Processed frame 1543 of 3204
# Processed frame 1544 of 3204
# Processed frame 1545 of 3204
# Processed frame 1546 of 3204
# Processed frame 1547 of 3204
# Processed frame 1548 of 3204
# Processed frame 1549 of 3204
# Processed frame 1550 of 3204
# Processed frame 1551 of 3204
# Processed frame 1552 of 3204
# Processed frame 1553 of 3204
# Processed frame 1554 of 3204
# Processed frame 1555 of 3204
# Processed frame 1556 of 3204
# Processed frame 1557 of 3204
# Processed frame 1558 of 3204
# Processed frame 1559 of 3204
# Processed frame 1560 of 3204
# Processed frame 1561 of 3204
# Processed frame 1562 of 3204
# Processed frame 1563 of 3204
# Processed frame 1564 of 3204
# Processed frame 1565 of 3204
# Processed frame 1566 of 3204
# Processed frame 1567 of 3204
# Processed frame 1568 of 3204
# Processed frame 1569 of 3204
# Processed frame 1570 of 3204
# Processed frame 1571 of 3204
# Processed frame 1572 of 3204
# Processed frame 1573 of 3204
# Processed frame 1574 of 3204
# Processed frame 1575 of 3204
# Processed frame 1576 of 3204
# Processed frame 1577 of 3204
# Processed frame 1578 of 3204
# Processed frame 1579 of 3204
# Processed frame 1580 of 3204
# Processed frame 1581 of 3204
# Processed frame 1582 of 3204
# Processed frame 1583 of 3204
# Processed frame 1584 of 3204
# Processed frame 1585 of 3204
# Processed frame 1586 of 3204
# Processed frame 1587 of 3204
# Processed frame 1588 of 3204
# Processed frame 1589 of 3204
# Processed frame 1590 of 3204
# Processed frame 1591 of 3204
# Processed frame 1592 of 3204
# Processed frame 1593 of 3204
# Processed frame 1594 of 3204
# Processed frame 1595 of 3204
# Processed frame 1596 of 3204
# Processed frame 1597 of 3204
# Processed frame 1598 of 3204
# Processed frame 1599 of 3204
# Processed frame 1600 of 3204
# Processed frame 1601 of 3204
# Processed frame 1602 of 3204
# Processed frame 1603 of 3204
# Processed frame 1604 of 3204
# Processed frame 1605 of 3204
# Processed frame 1606 of 3204
# Processed frame 1607 of 3204
# Processed frame 1608 of 3204
# Processed frame 1609 of 3204
# Processed frame 1610 of 3204
# Processed frame 1611 of 3204
# Processed frame 1612 of 3204
# Processed frame 1613 of 3204
# Processed frame 1614 of 3204
# Processed frame 1615 of 3204
# Processed frame 1616 of 3204
# Processed frame 1617 of 3204
# Processed frame 1618 of 3204
# Processed frame 1619 of 3204
# Processed frame 1620 of 3204
# Processed frame 1621 of 3204
# Processed frame 1622 of 3204
# Processed frame 1623 of 3204
# Processed frame 1624 of 3204
# Processed frame 1625 of 3204
# Processed frame 1626 of 3204
# Processed frame 1627 of 3204
# Processed frame 1628 of 3204
# Processed frame 1629 of 3204
# Processed frame 1630 of 3204
# Processed frame 1631 of 3204
# Processed frame 1632 of 3204
# Processed frame 1633 of 3204
# Processed frame 1634 of 3204
# Processed frame 1635 of 3204
# Processed frame 1636 of 3204
# Processed frame 1637 of 3204
# Processed frame 1638 of 3204
# Processed frame 1639 of 3204
# Processed frame 1640 of 3204
# Processed frame 1641 of 3204
# Processed frame 1642 of 3204
# Processed frame 1643 of 3204
# Processed frame 1644 of 3204
# Processed frame 1645 of 3204
# Processed frame 1646 of 3204
# Processed frame 1647 of 3204
# Processed frame 1648 of 3204
# Processed frame 1649 of 3204
# Processed frame 1650 of 3204
# Processed frame 1651 of 3204
# Processed frame 1652 of 3204
# Processed frame 1653 of 3204
# Processed frame 1654 of 3204
# Processed frame 1655 of 3204
# Processed frame 1656 of 3204
# Processed frame 1657 of 3204
# Processed frame 1658 of 3204
# Processed frame 1659 of 3204
# Processed frame 1660 of 3204
# Processed frame 1661 of 3204
# Processed frame 1662 of 3204
# Processed frame 1663 of 3204
# Processed frame 1664 of 3204
# Processed frame 1665 of 3204
# Processed frame 1666 of 3204
# Processed frame 1667 of 3204
# Processed frame 1668 of 3204
# Processed frame 1669 of 3204
# Processed frame 1670 of 3204
# Processed frame 1671 of 3204
# Processed frame 1672 of 3204
# Processed frame 1673 of 3204
# Processed frame 1674 of 3204
# Processed frame 1675 of 3204
# Processed frame 1676 of 3204
# ...
# Processed frame 2670 of 3204
# Processed frame 2671 of 3204
# Processed frame 2672 of 3204
# Processed frame 2673 of 3204
# Processed frame 2674 of 3204
# Processed frame 2675 of 3204
# Processed frame 2676 of 3204
# Processed frame 2677 of 3204
# Processed frame 2678 of 3204
# Processed frame 2679 of 3204
# Processed frame 2680 of 3204
# Processed frame 2681 of 3204
# Processed frame 2682 of 3204
# Processed frame 2683 of 3204
# Processed frame 2684 of 3204
# Processed frame 2685 of 3204
# Processed frame 2686 of 3204
# Processed frame 2687 of 3204
# Processed frame 2688 of 3204
# Processed frame 2689 of 3204
# Processed frame 2690 of 3204
# Processed frame 2691 of 3204
# Processed frame 2692 of 3204
# Processed frame 2693 of 3204
# Processed frame 2694 of 3204
# Processed frame 2695 of 3204
# Processed frame 2696 of 3204
# Processed frame 2697 of 3204
# Processed frame 2698 of 3204
# Processed frame 2699 of 3204
# Processed frame 2700 of 3204
# Processed frame 2701 of 3204
# Processed frame 2702 of 3204
# Processed frame 2703 of 3204
# Processed frame 2704 of 3204
# Processed frame 2705 of 3204
# Processed frame 2706 of 3204
# Processed frame 2707 of 3204
# Processed frame 2708 of 3204
# Processed frame 2709 of 3204
# Processed frame 2710 of 3204
# Processed frame 2711 of 3204
# Processed frame 2712 of 3204
# Processed frame 2713 of 3204
# Processed frame 2714 of 3204
# Processed frame 2715 of 3204
# Processed frame 2716 of 3204
# Processed frame 2717 of 3204
# Processed frame 2718 of 3204
# Processed frame 2719 of 3204
# Processed frame 2720 of 3204
# Processed frame 2721 of 3204
# Processed frame 2722 of 3204
# Processed frame 2723 of 3204
# Processed frame 2724 of 3204
# Processed frame 2725 of 3204
# Processed frame 2726 of 3204
# Processed frame 2727 of 3204
# Processed frame 2728 of 3204
# Processed frame 2729 of 3204
# Processed frame 2730 of 3204
# Processed frame 2731 of 3204
# Processed frame 2732 of 3204
# Processed frame 2733 of 3204
# Processed frame 2734 of 3204
# Processed frame 2735 of 3204
# Processed frame 2736 of 3204
# Processed frame 2737 of 3204
# Processed frame 2738 of 3204
# Processed frame 2739 of 3204
# Processed frame 2740 of 3204
# Processed frame 2741 of 3204
# Processed frame 2742 of 3204
# Processed frame 2743 of 3204
# Processed frame 2744 of 3204
# Processed frame 2745 of 3204
# Processed frame 2746 of 3204
# Processed frame 2747 of 3204
# Processed frame 2748 of 3204
# Processed frame 2749 of 3204
# Processed frame 2750 of 3204
# Processed frame 2751 of 3204
# Processed frame 2752 of 3204
# Processed frame 2753 of 3204
# Processed frame 2754 of 3204
# Processed frame 2755 of 3204
# Processed frame 2756 of 3204
# Processed frame 2757 of 3204
# Processed frame 2758 of 3204
# Processed frame 2759 of 3204
# Processed frame 2760 of 3204
# Processed frame 2761 of 3204
# Processed frame 2762 of 3204
# Processed frame 2763 of 3204
# Processed frame 2764 of 3204
# Processed frame 2765 of 3204
# Processed frame 2766 of 3204
# Processed frame 2767 of 3204
# Processed frame 2768 of 3204
# Processed frame 2769 of 3204
# Processed frame 2770 of 3204
# Processed frame 2771 of 3204
# Processed frame 2772 of 3204
# Processed frame 2773 of 3204
# Processed frame 2774 of 3204
# Processed frame 2775 of 3204
# Processed frame 2776 of 3204
# Processed frame 2777 of 3204
# Processed frame 2778 of 3204
# Processed frame 2779 of 3204
# Processed frame 2780 of 3204
# Processed frame 2781 of 3204
# Processed frame 2782 of 3204
# Processed frame 2783 of 3204
# Processed frame 2784 of 3204
# Processed frame 2785 of 3204
# Processed frame 2786 of 3204
# Processed frame 2787 of 3204
# Processed frame 2788 of 3204
# Processed frame 2789 of 3204
# Processed frame 2790 of 3204
# Processed frame 2791 of 3204
# Processed frame 2792 of 3204
# Processed frame 2793 of 3204
# Processed frame 2794 of 3204
# Processed frame 2795 of 3204
# Processed frame 2796 of 3204
# Processed frame 2797 of 3204
# Processed frame 2798 of 3204
# Processed frame 2799 of 3204
# Processed frame 2800 of 3204
# Processed frame 2801 of 3204
# Processed frame 2802 of 3204
# Processed frame 2803 of 3204
# Processed frame 2804 of 3204
# Processed frame 2805 of 3204
# Processed frame 2806 of 3204
# Processed frame 2807 of 3204
# Processed frame 2808 of 3204
# Processed frame 2809 of 3204
# Processed frame 2810 of 3204
# Processed frame 2811 of 3204
# Processed frame 2812 of 3204
# Processed frame 2813 of 3204
# Processed frame 2814 of 3204
# Processed frame 2815 of 3204
# Processed frame 2816 of 3204
# Processed frame 2817 of 3204
# Processed frame 2818 of 3204
# Processed frame 2819 of 3204
# Processed frame 2820 of 3204
# Processed frame 2821 of 3204
# Processed frame 2822 of 3204
# Processed frame 2823 of 3204
# Processed frame 2824 of 3204
# Processed frame 2825 of 3204
# Processed frame 2826 of 3204
# Processed frame 2827 of 3204
# Processed frame 2828 of 3204
# Processed frame 2829 of 3204
# Processed frame 2830 of 3204
# Processed frame 2831 of 3204
# Processed frame 2832 of 3204
# Processed frame 2833 of 3204
# Processed frame 2834 of 3204
# Processed frame 2835 of 3204
# Processed frame 2836 of 3204
# Processed frame 2837 of 3204
# Processed frame 2838 of 3204
# Processed frame 2839 of 3204
# Processed frame 2840 of 3204
# Processed frame 2841 of 3204
# Processed frame 2842 of 3204
# Processed frame 2843 of 3204
# Processed frame 2844 of 3204
# Processed frame 2845 of 3204
# Processed frame 2846 of 3204
# Processed frame 2847 of 3204
# Processed frame 2848 of 3204
# Processed frame 2849 of 3204
# Processed frame 2850 of 3204
# Processed frame 2851 of 3204
# Processed frame 2852 of 3204
# Processed frame 2853 of 3204
# Processed frame 2854 of 3204
# Processed frame 2855 of 3204
# Processed frame 2856 of 3204
# Processed frame 2857 of 3204
# Processed frame 2858 of 3204
# Processed frame 2859 of 3204
# Processed frame 2860 of 3204
# Processed frame 2861 of 3204
# Processed frame 2862 of 3204
# Processed frame 2863 of 3204
# Processed frame 2864 of 3204
# Processed frame 2865 of 3204
# Processed frame 2866 of 3204
# Processed frame 2867 of 3204
# Processed frame 2868 of 3204
# Processed frame 2869 of 3204
# Processed frame 2870 of 3204
# Processed frame 2871 of 3204
# Processed frame 2872 of 3204
# Processed frame 2873 of 3204
# Processed frame 2874 of 3204
# Processed frame 2875 of 3204
# Processed frame 2876 of 3204
# Processed frame 2877 of 3204
# Processed frame 2878 of 3204
# Processed frame 2879 of 3204
# Processed frame 2880 of 3204
# Processed frame 2881 of 3204
# Processed frame 2882 of 3204
# Processed frame 2883 of 3204
# Processed frame 2884 of 3204
# Processed frame 2885 of 3204
# Processed frame 2886 of 3204
# Processed frame 2887 of 3204
# Processed frame 2888 of 3204
# Processed frame 2889 of 3204
# Processed frame 2890 of 3204
# Processed frame 2891 of 3204
# Processed frame 2892 of 3204
# Processed frame 2893 of 3204
# Processed frame 2894 of 3204
# Processed frame 2895 of 3204
# Processed frame 2896 of 3204
# Processed frame 2897 of 3204
# Processed frame 2898 of 3204
# Processed frame 2899 of 3204
# Processed frame 2900 of 3204
# Processed frame 2901 of 3204
# Processed frame 2902 of 3204
# Processed frame 2903 of 3204
# Processed frame 2904 of 3204
# Processed frame 2905 of 3204
# Processed frame 2906 of 3204
# Processed frame 2907 of 3204
# Processed frame 2908 of 3204
# Processed frame 2909 of 3204
# Processed frame 2910 of 3204
# Processed frame 2911 of 3204
# Processed frame 2912 of 3204
# Processed frame 2913 of 3204
# Processed frame 2914 of 3204
# Processed frame 2915 of 3204
# Processed frame 2916 of 3204
# Processed frame 2917 of 3204
# Processed frame 2918 of 3204
# Processed frame 2919 of 3204
# Processed frame 2920 of 3204
# Processed frame 2921 of 3204
# Processed frame 2922 of 3204
# Processed frame 2923 of 3204
# Processed frame 2924 of 3204
# Processed frame 2925 of 3204
# Processed frame 2926 of 3204
# Processed frame 2927 of 3204
# Processed frame 2928 of 3204
# Processed frame 2929 of 3204
# Processed frame 2930 of 3204
# Processed frame 2931 of 3204
# Processed frame 2932 of 3204
# Processed frame 2933 of 3204
# Processed frame 2934 of 3204
# Processed frame 2935 of 3204
# Processed frame 2936 of 3204
# Processed frame 2937 of 3204
# Processed frame 2938 of 3204
# Processed frame 2939 of 3204
# Processed frame 2940 of 3204
# Processed frame 2941 of 3204
# Processed frame 2942 of 3204
# Processed frame 2943 of 3204
# Processed frame 2944 of 3204
# Processed frame 2945 of 3204
# Processed frame 2946 of 3204
# Processed frame 2947 of 3204
# Processed frame 2948 of 3204
# Processed frame 2949 of 3204
# Processed frame 2950 of 3204
# Processed frame 2951 of 3204
# Processed frame 2952 of 3204
# Processed frame 2953 of 3204
# Processed frame 2954 of 3204
# Processed frame 2955 of 3204
# Processed frame 2956 of 3204
# Processed frame 2957 of 3204
# Processed frame 2958 of 3204
# Processed frame 2959 of 3204
# Processed frame 2960 of 3204
# Processed frame 2961 of 3204
# Processed frame 2962 of 3204
# Processed frame 2963 of 3204
# Processed frame 2964 of 3204
# Processed frame 2965 of 3204
# Processed frame 2966 of 3204
# Processed frame 2967 of 3204
# Processed frame 2968 of 3204
# Processed frame 2969 of 3204
# Processed frame 2970 of 3204
# Processed frame 2971 of 3204
# Processed frame 2972 of 3204
# Processed frame 2973 of 3204
# Processed frame 2974 of 3204
# Processed frame 2975 of 3204
# Processed frame 2976 of 3204
# Processed frame 2977 of 3204
# Processed frame 2978 of 3204
# Processed frame 2979 of 3204
# Processed frame 2980 of 3204
# Processed frame 2981 of 3204
# Processed frame 2982 of 3204
# Processed frame 2983 of 3204
# Processed frame 2984 of 3204
# Processed frame 2985 of 3204
# Processed frame 2986 of 3204
# Processed frame 2987 of 3204
# Processed frame 2988 of 3204
# Processed frame 2989 of 3204
# Processed frame 2990 of 3204
# Processed frame 2991 of 3204
# Processed frame 2992 of 3204
# Processed frame 2993 of 3204
# Processed frame 2994 of 3204
# Processed frame 2995 of 3204
# Processed frame 2996 of 3204
# Processed frame 2997 of 3204
# Processed frame 2998 of 3204
# Processed frame 2999 of 3204
# Processed frame 3000 of 3204
# Finished writing /scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/2024-11-12-15-23-47_channel1_3.tiff
# Writing frames 3000 to 3203 to /scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/2024-11-12-15-23-47_channel1_4.tiff
# Processed frame 3001 of 3204
# Processed frame 3002 of 3204
# Processed frame 3003 of 3204
# Processed frame 3004 of 3204
# Processed frame 3005 of 3204
# Processed frame 3006 of 3204
# Processed frame 3007 of 3204
# Processed frame 3008 of 3204
# Processed frame 3009 of 3204
# Processed frame 3010 of 3204
# Processed frame 3011 of 3204
# Processed frame 3012 of 3204
# Processed frame 3013 of 3204
# Processed frame 3014 of 3204
# Processed frame 3015 of 3204
# Processed frame 3016 of 3204
# Processed frame 3017 of 3204
# Processed frame 3018 of 3204
# Processed frame 3019 of 3204
# Processed frame 3020 of 3204
# Processed frame 3021 of 3204
# Processed frame 3022 of 3204
# Processed frame 3023 of 3204
# Processed frame 3024 of 3204
# Processed frame 3025 of 3204
# Processed frame 3026 of 3204
# Processed frame 3027 of 3204
# Processed frame 3028 of 3204
# Processed frame 3029 of 3204
# Processed frame 3030 of 3204
# Processed frame 3031 of 3204
# Processed frame 3032 of 3204
# Processed frame 3033 of 3204
# Processed frame 3034 of 3204
# Processed frame 3035 of 3204
# Processed frame 3036 of 3204
# Processed frame 3037 of 3204
# Processed frame 3038 of 3204
# Processed frame 3039 of 3204
# Processed frame 3040 of 3204
# Processed frame 3041 of 3204
# Processed frame 3042 of 3204
# Processed frame 3043 of 3204
# Processed frame 3044 of 3204
# Processed frame 3045 of 3204
# Processed frame 3046 of 3204
# Processed frame 3047 of 3204
# Processed frame 3048 of 3204
# Processed frame 3049 of 3204
# Processed frame 3050 of 3204
# Processed frame 3051 of 3204
# Processed frame 3052 of 3204
# Processed frame 3053 of 3204
# Processed frame 3054 of 3204
# Processed frame 3055 of 3204
# Processed frame 3056 of 3204
# Processed frame 3057 of 3204
# Processed frame 3058 of 3204
# Processed frame 3059 of 3204
# Processed frame 3060 of 3204
# Processed frame 3061 of 3204
# Processed frame 3062 of 3204
# Processed frame 3063 of 3204
# Processed frame 3064 of 3204
# Processed frame 3065 of 3204
# Processed frame 3066 of 3204
# Processed frame 3067 of 3204
# Processed frame 3068 of 3204
# Processed frame 3069 of 3204
# Processed frame 3070 of 3204
# Processed frame 3071 of 3204
# Processed frame 3072 of 3204
# Processed frame 3073 of 3204
# Processed frame 3074 of 3204
# Processed frame 3075 of 3204
# Processed frame 3076 of 3204
# Processed frame 3077 of 3204
# Processed frame 3078 of 3204
# Processed frame 3079 of 3204
# Processed frame 3080 of 3204
# Processed frame 3081 of 3204
# Processed frame 3082 of 3204
# Processed frame 3083 of 3204
# Processed frame 3084 of 3204
# Processed frame 3085 of 3204
# Processed frame 3086 of 3204
# Processed frame 3087 of 3204
# Processed frame 3088 of 3204
# Processed frame 3089 of 3204
# Processed frame 3090 of 3204
# Processed frame 3091 of 3204
# Processed frame 3092 of 3204
# Processed frame 3093 of 3204
# Processed frame 3094 of 3204
# Processed frame 3095 of 3204
# Processed frame 3096 of 3204
# Processed frame 3097 of 3204
# Processed frame 3098 of 3204
# Processed frame 3099 of 3204
# Processed frame 3100 of 3204
# Processed frame 3101 of 3204
# Processed frame 3102 of 3204
# Processed frame 3103 of 3204
# Processed frame 3104 of 3204
# Processed frame 3105 of 3204
# Processed frame 3106 of 3204
# Processed frame 3107 of 3204
# Processed frame 3108 of 3204
# Processed frame 3109 of 3204
# Processed frame 3110 of 3204
# Processed frame 3111 of 3204
# Processed frame 3112 of 3204
# Processed frame 3113 of 3204
# Processed frame 3114 of 3204
# Processed frame 3115 of 3204
# Processed frame 3116 of 3204
# Processed frame 3117 of 3204
# Processed frame 3118 of 3204
# Processed frame 3119 of 3204
# Processed frame 3120 of 3204
# Processed frame 3121 of 3204
# Processed frame 3122 of 3204
# Processed frame 3123 of 3204
# Processed frame 3124 of 3204
# Processed frame 3125 of 3204
# Processed frame 3126 of 3204
# Processed frame 3127 of 3204
# Processed frame 3128 of 3204
# Processed frame 3129 of 3204
# Processed frame 3130 of 3204
# Processed frame 3131 of 3204
# Processed frame 3132 of 3204
# Processed frame 3133 of 3204
# Processed frame 3134 of 3204
# Processed frame 3135 of 3204
# Processed frame 3136 of 3204
# Processed frame 3137 of 3204
# Processed frame 3138 of 3204
# Processed frame 3139 of 3204
# Processed frame 3140 of 3204
# Processed frame 3141 of 3204
# Processed frame 3142 of 3204
# Processed frame 3143 of 3204
# Processed frame 3144 of 3204
# Processed frame 3145 of 3204
# Processed frame 3146 of 3204
# Processed frame 3147 of 3204
# Processed frame 3148 of 3204
# Processed frame 3149 of 3204
# Processed frame 3150 of 3204
# Processed frame 3151 of 3204
# Processed frame 3152 of 3204
# Processed frame 3153 of 3204
# Processed frame 3154 of 3204
# Processed frame 3155 of 3204
# Processed frame 3156 of 3204
# Processed frame 3157 of 3204
# Processed frame 3158 of 3204
# Processed frame 3159 of 3204
# Processed frame 3160 of 3204
# Processed frame 3161 of 3204
# Processed frame 3162 of 3204
# Processed frame 3163 of 3204
# Processed frame 3164 of 3204
# Processed frame 3165 of 3204
# Processed frame 3166 of 3204
# Processed frame 3167 of 3204
# Processed frame 3168 of 3204
# Processed frame 3169 of 3204
# Processed frame 3170 of 3204
# Processed frame 3171 of 3204
# Processed frame 3172 of 3204
# Processed frame 3173 of 3204
# Processed frame 3174 of 3204
# Processed frame 3175 of 3204
# Processed frame 3176 of 3204
# Processed frame 3177 of 3204
# Processed frame 3178 of 3204
# Processed frame 3179 of 3204
# Processed frame 3180 of 3204
# Processed frame 3181 of 3204
# Processed frame 3182 of 3204
# Processed frame 3183 of 3204
# Processed frame 3184 of 3204
# Processed frame 3185 of 3204
# Processed frame 3186 of 3204
# Processed frame 3187 of 3204
# Processed frame 3188 of 3204
# Processed frame 3189 of 3204
# Processed frame 3190 of 3204
# Processed frame 3191 of 3204
# Processed frame 3192 of 3204
# Processed frame 3193 of 3204
# Processed frame 3194 of 3204
# Processed frame 3195 of 3204
# Processed frame 3196 of 3204
# Processed frame 3197 of 3204
# Processed frame 3198 of 3204
# Processed frame 3199 of 3204
# Processed frame 3200 of 3204
# Processed frame 3201 of 3204
# Processed frame 3202 of 3204
# Processed frame 3203 of 3204
# Processed frame 3204 of 3204
# Finished writing /scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/2024-11-12-15-23-47_channel1_4.tiff
# All TIFF files have been saved.

# %%
# Open the HDF5 file and read dataset shape
with h5py.File(dirPath + filePath, 'r') as f_in:
    dset = f_in['data']
    total_frames, height, width = dset.shape
    print("Dataset shape:", dset.shape)

    # Create an imageio writer; codec "rawvideo" should give you an uncompressed output
    writer = imageio.get_writer(output_avi, fps=fps, codec='rawvideo')
    
    for i in range(total_frames):
        frame = dset[i, :, :]
        # If the frame is not uint8, scale it appropriately.
        if frame.dtype != np.uint8:
            frame = ((frame - frame.min()) / (frame.max() - frame.min()) * 255).astype(np.uint8)
        writer.append_data(frame)
    writer.close()

print(f"Saved {total_frames} frames to {output_avi} as an uncompressed AVI.")
# Out:
# Dataset shape: (3204, 1280, 800)
# Saved 3204 frames to /scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1.avi as an uncompressed AVI.

# %%
# after motion correction convert tiffs back to h5

# get tiff files
tiff_dir = "/scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/motion_corrected"
tiff_files = sorted(glob.glob(os.path.join(tiff_dir, "*.tif")))

# %%
tiff_files
# Out:
# ['/scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/motion_corrected/2024-11-12-15-23-47_channel1_tiff_output2024-11-12-15-23-47_channel1_01___motion_corrected.tif',
#  '/scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/motion_corrected/2024-11-12-15-23-47_channel1_tiff_output2024-11-12-15-23-47_channel1_02___motion_corrected.tif',
#  '/scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/motion_corrected/2024-11-12-15-23-47_channel1_tiff_output2024-11-12-15-23-47_channel1_03___motion_corrected.tif',
#  '/scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/motion_corrected/2024-11-12-15-23-47_channel1_tiff_output2024-11-12-15-23-47_channel1_04___motion_corrected.tif']

# %%
output_h5 = '/scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/motion_corrected_combined_dataset.h5'
tiffs_to_h5(tiff_dir, output_h5, dataset_name='data', chunk_size=100, swap_axes=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 output_h5 = '/scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/motion_corrected_combined_dataset.h5'
# ----> 2 tiffs_to_h5(tiff_dir, output_h5, dataset_name='data', chunk_size=100, swap_axes=False)
#
# Cell In[12], line 147, in tiffs_to_h5(tiff_dir, output_h5, dataset_name, chunk_size, swap_axes)
#     145     if common_shape != shape:
#     146         reader.close()
# --> 147         raise ValueError(f"Inconsistent frame shapes: expected {common_shape} but got {shape} in {tiff_file}")
#     149 total_frames += n_frames_file
#     150 file_info.append((tiff_file, n_frames_file))
#
# ValueError: Inconsistent frame shapes: expected (1000, 1280) but got (204, 1280) in /scratch/jma819/scope_data/SPRT/m1_GRAB_analysis/2024-11-12-15-23-47_channel1_tiff_output/motion_corrected/2024-11-12-15-23-47_channel1_tiff_output2024-11-12-15-23-47_channel1_04___motion_corrected.tif

# %%
tiff_dir = '/Users/johnmarshall/Documents/Analysis/nVueData/SPRT/SPRT_m1_d6/2024-11-12-15-23-47_channel1_tiff_output/'
tiff_files = sorted(glob.glob(os.path.join(tiff_dir, "*.tif")))

file_info = []       # list of tuples: (filename, n_frames)
totalFrames = 0; 
for tiff_file in tiff_files:
    reader = imageio.get_reader(tiff_file, format='TIFF')
    n_pages = reader.get_length()
    totalFrames = totalFrames + n_pages
    frame0 = reader.get_data(0)
    print(f"File: {os.path.basename(tiff_file)}")
    print(f"  Number of pages/frames: {n_pages}")
    print(f"  First frame shape: {frame0.shape}\n")
    reader.close()
    common_shape = (frame0.shape)
    file_info.append((tiff_file, n_pages))
totalFrames
# Out:
# File: 2024-11-12-15-23-47_channel1_01.tif
#   Number of pages/frames: 1000
#   First frame shape: (1280, 800)
#
# File: 2024-11-12-15-23-47_channel1_02.tif
#   Number of pages/frames: 1000
#   First frame shape: (1280, 800)
#
# File: 2024-11-12-15-23-47_channel1_03.tif
#   Number of pages/frames: 1000
#   First frame shape: (1280, 800)
#
# File: 2024-11-12-15-23-47_channel1_04.tif
#   Number of pages/frames: 204
#   First frame shape: (1280, 800)
# 3204

# %%
chunk_size = 100
output_h5 = '/Users/johnmarshall/Documents/Analysis/nVueData/SPRT/SPRT_m1_d6/2024-11-12-15-23-47_channel1_tiff_output/h5_outTest.h5'

current_index = 0
with h5py.File(output_h5, 'w') as f_out:
    dataset_name = 'data' 
    dset = f_out.create_dataset(dataset_name, shape=(totalFrames, common_shape[0], common_shape[1]),
                                    dtype=np.uint8, chunks=True)
    for tiff_file, n_frames_file in file_info:
        reader = imageio.get_reader(tiff_file, format='TIFF')
        frame0 = reader.get_data(0)
        n_slices = n_frames_file
        for start in range(0, n_slices, chunk_size):
            end = min(start + chunk_size, n_slices)
            frames = np.array([reader.get_data(i) for i in range(start, end)])
            num_chunk = frames.shape[0]
            dset[current_index:current_index+num_chunk, :, :] = frames
            current_index += num_chunk

# %%
np.shape(frames)
# Out:
# (4, 1280, 800)

# %%
frames.dtype
# Out:
# dtype('uint8')

# %%
end
# Out:
# 204
